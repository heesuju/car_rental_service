# %%
import car_rental.rental as r

rental = r.Rental()

rental.fleet.add_car("sonata05", "Sonata", True)
rental.fleet.show_available()
rental.clients.show_users()
rental.clients.rent_car("joe", "sonata05")
rental.fleet.get_car("sonata05").move(200)
rental.fleet.get_car("sonata05").fill_up()
rental.fleet.get_car("sonata05").ride(2)
rental.fleet.get_car("sonata05").move(40)
rental.fleet.get_car("sonata05").ride(2)
rental.fleet.get_car("sonata05").move(20)
rental.fleet.get_car("sonata05").drop(1)
rental.fleet.get_car("sonata05").move(50)
rental.fleet.get_car("sonata05").show_dash()
rental.clients.return_car("joe", "sonata05")

rental.fleet.get_best_match(used_state = False, fuel_economy = 10)

rental.clients.rent_car("joe", "bongo02")
rental.fleet.get_car("bongo02").move(200)
rental.fleet.get_car("bongo02").show_dash()
rental.clients.get_user("joe").get_rental_period("sonata05")

rental.monitor.show_event_count_week("fuel")
rental.monitor.show_event_count_week("move")
rental.monitor.show_event_count_week("rental")
rental.monitor.show_event_count_week("return")
rental.monitor.show_event_count_week("add")
rental.monitor.show_event_count_week("delete")

rental.monitor.show_event_count_week("fuel")
rental.monitor.show_event_count_week("move")
rental.monitor.show_event_count_week("rental")
rental.monitor.show_event_count_week("return")
rental.monitor.show_event_count_week("add")
rental.monitor.show_event_count_week("delete")
# Out:
# sonata05 차량이 추가되었습니다.
# 대여 가능한 차량 목록:
# id: bongo02, 차종: Bongo, 최대 연료량: 55리터, 연비: 11km/l, 최대 적재무게: 0kg, 렌탈여부: False, 마일리지: 300km, 상태: 신차
# id: sonata05, 차종: Sonata, 최대 연료량: 55리터, 연비: 12km/l, 최대 탑승인웡: 4명, 렌탈여부: False, 마일리지: 50000km, 상태: 중고
# 사용자명: alex, 렌탈차: ['sonata01', 'sonata003']
# 사용자명: judy, 렌탈차: ['tucson01', 'tucson003']
# 사용자명: bob, 렌탈차: ['bongo007']
# 사용자명: joe, 렌탈차: []
# 사용자명: rob, 렌탈차: []
# 사용자명: rick, 렌탈차: ['tesla01', 'tesla005']
# 사용자명: morty, 렌탈차: []
# 사용자명: smith, 렌탈차: ['sonata03', 'tesla02']
# joe 고객님이 sonata05 차량을 렌탈했습니다.
# sonata05 차량은 198.00km 주행하다 멈췄습니다.
# sonata05 차량에 55.00리터를 주유했습니다.
# sonata05 차량에 2명이 탑승했습니다.
# sonata05 차량은 40.00km 주행했습니다.
# sonata05 차량에 2명이 탑승했습니다.
# sonata05 차량은 20.00km 주행했습니다.
# sonata05 차량에서 1명이 내렸습니다.
# sonata05 차량은 50.00km 주행했습니다.
# sonata05의 대시보드
# 총 운행거리 : 50308.00km
# 현재 연료량 : 45.13리터
# 현재 연료량으로 주행 가능 거리 : 501.00km
# 최근 100km 주행 간 연비 : 11.13km/l
# 탑승인원 : 3명
#
# joe 고객님이 sonata05 차량을 반환했습니다.
# 모든 승객이 내렸습니다.
# ...
